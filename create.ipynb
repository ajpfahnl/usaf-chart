# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.dpi'] = 100

# %load_ext autoreload
# %autoreload 2

from CreateUSAF import *

# %%
usaf = CreateUSAF(bar_width=50, bar_height=400, groups=10, scale=1.3)
chart = usaf.create_raster()
plt.imshow(chart, cmap=plt.get_cmap('gray'),vmin=0,vmax=255)

# %%
usaf = CreateUSAF(bar_width=20, bar_height=200, groups=10, scale=1.3)
chart = usaf.create_raster_old()
plt.imshow(chart, cmap=plt.get_cmap('gray'),vmin=0,vmax=255)
